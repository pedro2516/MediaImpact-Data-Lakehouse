# %%
from os import PathLike
from hdfs import InsecureClient
from pyspark.sql import SparkSession
from pyspark.sql import Row
from delta import *
from pyspark.sql.types import LongType, StringType, StructField, StructType, BooleanType, ArrayType, IntegerType, DoubleType

# %%
# warehouse_location points to the default location for managed databases and tables
warehouse_location = 'hdfs://hdfs-nn:9000/warehouse'

builder = SparkSession \
    .builder \
    .appName("Python Spark SQL Hive integration for the EDSTD project") \
    .config("spark.sql.warehouse.dir", warehouse_location) \
    .config("hive.metastore.uris", "thrift://hive-metastore:9083") \
    .config("spark.sql.extensions", "io.delta.sql.DeltaSparkSessionExtension") \
    .config("spark.sql.catalog.spark_catalog", "org.apache.spark.sql.delta.catalog.DeltaCatalog") \
    .config("spark.jars.packages", "io.delta:delta-core_2.12:1.0.0") \
    .enableHiveSupport() \

spark = spark = configure_spark_with_delta_pip(builder).getOrCreate()

# %%
spark.sql(
    """
    SHOW TABLES FROM projeto
    """
).show()
# Out:
# +---------+---------------+-----------+
# |namespace|      tableName|isTemporary|
# +---------+---------------+-----------+
# |  projeto| amazon_credits|      false|
# |  projeto|  amazon_titles|      false|
# |  projeto|netflix_credits|      false|
# |  projeto| netflix_titles|      false|
# +---------+---------------+-----------+

# %%
# spark.sql(
#    """
#    DROP TABLE IF EXISTS projeto.amazon_titles
#    """
#)
# Out:
# DataFrame[]

# %%
spark.sql("""
    CREATE EXTERNAL TABLE projeto.amazon_titles (
        id VARCHAR(50),
        title VARCHAR(130),
        type VARCHAR(5),
        description VARCHAR(2200),
        release_year INT,
        age_certification VARCHAR(5),
        runtime INT,
        production_countries VARCHAR(50),
        seasons DOUBLE,
        imdb_id VARCHAR(10),
        imdb_score DOUBLE,
        imdb_votes DOUBLE,
        tmdb_popularity DOUBLE,
        tmdb_score DOUBLE,
        genre_scifi integer,
        genre_documentation integer,
        genre_crime integer,
        genre_fantasy integer,
        genre_action integer,
        genre_animation integer,
        genre_sport integer, 
        genre_family integer, 
        genre_horror integer,
        genre_history integer, 
        genre_music integer,
        genre_drama integer, 
        genre_western integer, 
        genre_war integer, 
        genre_european integer, 
        genre_romance integer, 
        genre_thriller integer, 
        genre_reality integer, 
        genre_comedy integer 
    )
    USING DELTA
    PARTITIONED BY (release_year)
    LOCATION 'hdfs://hdfs-nn:9000/warehouse/projeto.db/amazon_titles/'
"""
)
# Out:
# DataFrame[]

# %%
spark.sql(
    """
    DESCRIBE FORMATTED projeto.amazon_titles
    """
).toPandas()
# Out:
#                         col_name  \
# 0                             id
# 1                          title
# 2                           type
# 3                    description
# 4                   release_year
# 5              age_certification
# 6                        runtime
# 7                         genres
# 8           production_countries
# 9                        seasons
# 10                       imdb_id
# 11                    imdb_score
# 12                    imdb_votes
# 13               tmdb_popularity
# 14                    tmdb_score
# 15       # Partition Information
# 16                    # col_name
# 17                  release_year
# 18
# 19  # Detailed Table Information
# 20                          Name
# 21                          Type
# 22                      Location
# 23                      Provider
# 24                         Owner
# 25              Table Properties
#
#                                             data_type  comment
# 0                                              string     None
# 1                                              string     None
# 2                                              string     None
# 3                                              string     None
# 4                                                 int     None
# 5                                              string     None
# 6                                                 int     None
# 7                                              string     None
# 8                                              string     None
# 9                                              double     None
# 10                                             string     None
# 11                                             double     None
# 12                                             double     None
# 13                                             double     None
# 14                                             double     None
# 15
# 16                                          data_type  comment
# 17                                                int     None
# 18
# 19
# 20                spark_catalog.projeto.amazon_titles
# 21                                           EXTERNAL
# 22  hdfs://hdfs-nn:9000/warehouse/projeto.db/amazo...
# 23                                              delta
# 24                                             jovyan
# 25  [delta.minReaderVersion=1,delta.minWriterVersi...

# %%
spark.sql(
    """
    SELECT * FROM projeto.amazon_titles
    """
).show()
# Out:
# +-------+--------------------+-----+--------------------+------------+-----------------+-------+--------------------+--------------------+-------+---------+----------+----------+---------------+----------+
# |     id|               title| type|         description|release_year|age_certification|runtime|              genres|production_countries|seasons|  imdb_id|imdb_score|imdb_votes|tmdb_popularity|tmdb_score|
# +-------+--------------------+-----+--------------------+------------+-----------------+-------+--------------------+--------------------+-------+---------+----------+----------+---------------+----------+
# | tm7320|  The Usual Suspects|MOVIE|Held in an L.A. i...|        1995|                R|    106|['thriller', 'cri...|              ['US']|   null|tt0114814|       8.5| 1059480.0|         22.233|       8.2|
# |tm12503|          Braveheart|MOVIE|Enraged at the sl...|        1995|                R|    177|['drama', 'histor...|              ['US']|   null|tt0112573|       8.4| 1016629.0|         42.208|       7.9|
# | tm7806|           GoldenEye|MOVIE|When a powerful R...|        1995|            PG-13|    130|['action', 'thril...|        ['GB', 'US']|   null|tt0113189|       7.2|  253750.0|         19.489|       6.9|
# |tm13668|           Tank Girl|MOVIE|Based on the Brit...|        1995|                R|     98|['fantasy', 'acti...|              ['US']|   null|tt0114614|       5.3|   31870.0|         10.879|       5.4|
# |tm11518|             Species|MOVIE|In 1993, the Sear...|        1995|                R|    108|['scifi', 'thrill...|              ['US']|   null|tt0114508|       5.8|   79453.0|         26.988|       5.9|
# | tm7517|The City of Lost ...|MOVIE|A scientist in a ...|        1995|                R|    108|['scifi', 'europe...|  ['ES', 'FR', 'DE']|   null|tt0112682|       7.5|   68070.0|         11.382|       7.4|
# |tm12720|        Nick of Time|MOVIE|An unimpressive, ...|        1995|                R|     90|['thriller', 'act...|              ['US']|   null|tt0113972|       6.3|   41853.0|         12.926|       6.2|
# |ts29317|      Hamish Macbeth| SHOW|Hamish Macbeth is...|        1995|             null|     49|['drama', 'comedy...|              ['GB']|    3.0|tt0111993|       7.8|    1993.0|          9.083|       7.8|
# |tm11338|The Indian in the...|MOVIE|A nine-year-old b...|        1995|               PG|     96|['family', 'fanta...|              ['US']|   null|tt0113419|       6.0|   28697.0|         37.898|       6.4|
# |tm14255|  Living in Oblivion|MOVIE|Nick is the direc...|        1995|                R|     89| ['drama', 'comedy']|              ['US']|   null|tt0113677|       7.5|   18410.0|          7.647|       7.2|
# |tm13244| Vampire in Brooklyn|MOVIE|Maximillian, the ...|        1995|                R|    100|['comedy', 'fanta...|              ['US']|   null|tt0114825|       4.6|   23387.0|         13.053|       5.0|
# | tm8836|Dilwale Dulhania ...|MOVIE|Raj is a rich, ca...|        1995|                G|    181|['drama', 'romance']|              ['IN']|   null|tt0112870|       8.0|   68213.0|         21.709|       8.7|
# | tm7854|           Wild Bill|MOVIE|Biopic about famo...|        1995|                R|    100|['western', 'acti...|              ['US']|   null|tt0114938|       5.8|    7013.0|          10.03|       5.8|
# |tm14199|Gamera: Guardian ...|MOVIE|A ship runs agrou...|        1995|             null|     96|['horror', 'fanta...|              ['JP']|   null|tt0113142|       6.7|    3452.0|          8.408|       7.7|
# | tm9355|               Fluke|MOVIE|Workaholic Thomas...|        1995|               PG|     96|['drama', 'fantas...|              ['US']|   null|tt0113089|       6.6|    6952.0|         11.401|       7.2|
# | tm8268|When Night Is Fal...|MOVIE|A prudish woman w...|        1995|                R|     96|['drama', 'romance']|              ['CA']|   null|tt0114916|       6.5|    7040.0|          9.442|       6.2|
# |tm12713|The New Adventure...|MOVIE|Hop into a deligh...|        1995|             null|     48|       ['animation']|              ['US']|   null|     null|      null|      null|          1.143|       5.6|
# |tm10483|             Jeffrey|MOVIE|Jeffrey, a gay ma...|        1995|                R|     92|['comedy', 'drama...|              ['US']|   null|tt0113464|       6.7|    6241.0|          3.447|       6.8|
# |ts67359|Liz: The Elizabet...| SHOW|The story of the ...|        1995|             null|     89|           ['drama']|              ['US']|    1.0|     null|      null|      null|          5.091|       6.3|
# | tm9460|              Sahara|MOVIE|After the fall of...|        1995|             null|    106|   ['action', 'war']|        ['AU', 'US']|   null|tt0332176|       6.7|    3140.0|          7.518|       6.5|
# +-------+--------------------+-----+--------------------+------------+-----------------+-------+--------------------+--------------------+-------+---------+----------+----------+---------------+----------+
# only showing top 20 rows

# %%
spark.sql(
    """
    DESCRIBE HISTORY projeto.amazon_titles
    """
).show()
